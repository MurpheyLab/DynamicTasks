# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def barrier(x):
    return 100.*((x-1.5)/10)**8

data = []
xx = np.random.uniform(0,3,(100,2))
for x in xx:
    data.append(barrier(x))

# %%
data = np.array(data)
plt.plot(xx,data,'*')
plt.show()
